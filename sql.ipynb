# %%
from sqlalchemy import *
import numpy as np
import pandas as pd
import os
import winsound
frequency = 2500  # Set Frequency To 2500 Hertz
duration = 1500  # Set Duration To 1000 ms == 1 second
directory = os.getcwd()
directory
# Out:
# 'C:\\Users\\hknighton\\dump'

# %%
import time, sys
from IPython.display import clear_output
def update_progress(progress):
    bar_length = 20
    if isinstance(progress, int):
        progress = float(progress)
    if not isinstance(progress, float):
        progress = 0
    if progress < 0:
        progress = 0
    if progress >= 1:
        progress = 1
    block = int(round(bar_length * progress))
    clear_output(wait = True)
    text = "Progress: [{0}] {1:.1f}%".format( "#" * block + "-" * (bar_length - block), progress * 100)
    print(text)

# %%
engine = create_engine('mysql://root:password!@localhost:3306/ceesmart')

# %%
connection = engine.connect()

# %%
num_files = 0
for filename in os.listdir(directory):
    if filename.endswith(".csv"): 
        num_files +=1
num_files
# Out:
# 906

# %%
i = 1
for filename in os.listdir(directory):
    if filename.endswith(".csv"): 
        with open(filename, 'r') as file:
            data = pd.read_csv(file)
            file2 = str(file)
            data = data[pd.notnull(data['Time'])]
            data = data.drop_duplicates()
        data.to_sql("hourlydata", con=engine, index=True, index_label='id', if_exists='append')
        print(i)
        i = i + 1
        update_progress(i/num_files)

winsound.Beep(frequency, duration)
# Out:
# Progress: [####################] 100.0%

# %%
engine = nothing

# %%
connection = engine.connect()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\pool.py in unique_connection(self)
#     341         """
# --> 342         return _ConnectionFairy._checkout(self)
#     343
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\pool.py in _checkout(cls, pool, threadconns, fairy)
#     787         if not fairy:
# --> 788             fairy = _ConnectionRecord.checkout(pool)
#     789
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\pool.py in checkout(cls, pool)
#     528     def checkout(cls, pool):
# --> 529         rec = pool._do_get()
#     530         try:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\pool.py in _do_get(self)
#    1192                 with util.safe_reraise():
# -> 1193                     self._dec_overflow()
#    1194         else:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      65             if not self.warn_only:
# ---> 66                 compat.reraise(exc_type, exc_value, exc_tb)
#      67         else:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     248             raise value.with_traceback(tb)
# --> 249         raise value
#     250
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\pool.py in _do_get(self)
#    1189             try:
# -> 1190                 return self._create_connection()
#    1191             except:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\pool.py in _create_connection(self)
#     346
# --> 347         return _ConnectionRecord(self)
#     348
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\pool.py in __init__(self, pool, connect)
#     473         if connect:
# --> 474             self.__connect(first_connect_check=True)
#     475         self.finalize_callback = deque()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\pool.py in __connect(self, first_connect_check)
#     670             self.starttime = time.time()
# --> 671             connection = pool._invoke_creator(self)
#     672             pool.logger.debug("Created new connection %r", connection)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     105                             return connection
# --> 106                 return dialect.connect(*cargs, **cparams)
#     107
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     411     def connect(self, *cargs, **cparams):
# --> 412         return self.dbapi.connect(*cargs, **cparams)
#     413
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\MySQLdb\__init__.py in Connect(*args, **kwargs)
#      84     from MySQLdb.connections import Connection
# ---> 85     return Connection(*args, **kwargs)
#      86
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\MySQLdb\connections.py in __init__(self, *args, **kwargs)
#     207
# --> 208         super(Connection, self).__init__(*args, **kwargs2)
#     209         self.cursorclass = cursorclass
#
# OperationalError: (2006, "Access denied for user 'root'@'HKNIGHTON-LT.RTTS.local' (using password: YES)")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-15-1bc28d4923ee> in <module>
# ----> 1 connection = engine.connect()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in connect(self, **kwargs)
#    2100         """
#    2101
# -> 2102         return self._connection_cls(self, **kwargs)
#    2103
#    2104     def contextual_connect(self, close_with_result=False, **kwargs):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events)
#      88         else:
#      89             self.__connection = connection \
# ---> 90                 if connection is not None else engine.raw_connection()
#      91             self.__transaction = None
#      92             self.__savepoint_seq = 0
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in raw_connection(self, _connection)
#    2186         """
#    2187         return self._wrap_pool_connect(
# -> 2188             self.pool.unique_connection, _connection)
#    2189
#    2190
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2160             if connection is None:
#    2161                 Connection._handle_dbapi_exception_noconnection(
# -> 2162                     e, dialect, self)
#    2163             else:
#    2164                 util.reraise(*sys.exc_info())
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1474             util.raise_from_cause(
#    1475                 sqlalchemy_exception,
# -> 1476                 exc_info
#    1477             )
#    1478         else:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     263     exc_type, exc_value, exc_tb = exc_info
#     264     cause = exc_value if exc_value is not exception else None
# --> 265     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     266
#     267 if py3k:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     246             value.__cause__ = cause
#     247         if value.__traceback__ is not tb:
# --> 248             raise value.with_traceback(tb)
#     249         raise value
#     250
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2156         dialect = self.dialect
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#    2160             if connection is None:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\pool.py in unique_connection(self)
#     340
#     341         """
# --> 342         return _ConnectionFairy._checkout(self)
#     343
#     344     def _create_connection(self):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\pool.py in _checkout(cls, pool, threadconns, fairy)
#     786     def _checkout(cls, pool, threadconns=None, fairy=None):
#     787         if not fairy:
# --> 788             fairy = _ConnectionRecord.checkout(pool)
#     789
#     790             fairy._pool = pool
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\pool.py in checkout(cls, pool)
#     527     @classmethod
#     528     def checkout(cls, pool):
# --> 529         rec = pool._do_get()
#     530         try:
#     531             dbapi_connection = rec.get_connection()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\pool.py in _do_get(self)
#    1191             except:
#    1192                 with util.safe_reraise():
# -> 1193                     self._dec_overflow()
#    1194         else:
#    1195             return self._do_get()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      64             self._exc_info = None   # remove potential circular references
#      65             if not self.warn_only:
# ---> 66                 compat.reraise(exc_type, exc_value, exc_tb)
#      67         else:
#      68             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     247         if value.__traceback__ is not tb:
#     248             raise value.with_traceback(tb)
# --> 249         raise value
#     250
#     251 else:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\pool.py in _do_get(self)
#    1188         if self._inc_overflow():
#    1189             try:
# -> 1190                 return self._create_connection()
#    1191             except:
#    1192                 with util.safe_reraise():
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\pool.py in _create_connection(self)
#     345         """Called by subclasses to create a new ConnectionRecord."""
#     346
# --> 347         return _ConnectionRecord(self)
#     348
#     349     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\pool.py in __init__(self, pool, connect)
#     472         self.__pool = pool
#     473         if connect:
# --> 474             self.__connect(first_connect_check=True)
#     475         self.finalize_callback = deque()
#     476
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\pool.py in __connect(self, first_connect_check)
#     669         try:
#     670             self.starttime = time.time()
# --> 671             connection = pool._invoke_creator(self)
#     672             pool.logger.debug("Created new connection %r", connection)
#     673             self.connection = connection
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     104                         if connection is not None:
#     105                             return connection
# --> 106                 return dialect.connect(*cargs, **cparams)
#     107
#     108             creator = pop_kwarg('creator', connect)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     410
#     411     def connect(self, *cargs, **cparams):
# --> 412         return self.dbapi.connect(*cargs, **cparams)
#     413
#     414     def create_connect_args(self, url):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\MySQLdb\__init__.py in Connect(*args, **kwargs)
#      83     """Factory function for connections.Connection."""
#      84     from MySQLdb.connections import Connection
# ---> 85     return Connection(*args, **kwargs)
#      86
#      87 connect = Connection = Connect
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\MySQLdb\connections.py in __init__(self, *args, **kwargs)
#     206                  DeprecationWarning, 2)
#     207
# --> 208         super(Connection, self).__init__(*args, **kwargs2)
#     209         self.cursorclass = cursorclass
#     210         self.encoders = dict([ (k, v) for k, v in conv.items()
#
# OperationalError: (_mysql_exceptions.OperationalError) (2006, "Access denied for user 'root'@'HKNIGHTON-LT.RTTS.local' (using password: YES)") (Background on this error at: http://sqlalche.me/e/e3q8)

# %%
data = pd.read_csv('SoCal_Rainbow Station_Run 2_22-05-2019 672850439 Hourly.csv')
data.iloc[400,1]
data = data[pd.notnull(data['Time'])]

data = data.drop_duplicates()
data
# Out:
#                     Time                Station  % Comm to USM  % Comm to GC  \
# 0    05/06/2019 10:00 AM  Rainbow Station Run_2          100.0         100.0
# 1    05/06/2019 11:00 AM  Rainbow Station Run_2          100.0         100.0
# 2    05/06/2019 12:00 PM  Rainbow Station Run_2          100.0         100.0
# 3     05/06/2019 1:00 PM  Rainbow Station Run_2          100.0         100.0
# 4     05/06/2019 2:00 PM  Rainbow Station Run_2          100.0         100.0
# 5     05/06/2019 3:00 PM  Rainbow Station Run_2          100.0         100.0
# 6     05/06/2019 4:00 PM  Rainbow Station Run_2          100.0         100.0
# 7     05/06/2019 5:00 PM  Rainbow Station Run_2          100.0         100.0
# 8     05/06/2019 6:00 PM  Rainbow Station Run_2          100.0         100.0
# 9     05/06/2019 7:00 PM  Rainbow Station Run_2          100.0         100.0
# 10    05/06/2019 8:00 PM  Rainbow Station Run_2          100.0         100.0
# 11    05/06/2019 9:00 PM  Rainbow Station Run_2          100.0         100.0
# 12   05/06/2019 10:00 PM  Rainbow Station Run_2          100.0         100.0
# 13   05/06/2019 11:00 PM  Rainbow Station Run_2          100.0         100.0
# 14   05/07/2019 12:00 AM  Rainbow Station Run_2          100.0         100.0
# 15    05/07/2019 1:00 AM  Rainbow Station Run_2          100.0         100.0
# 16    05/07/2019 2:00 AM  Rainbow Station Run_2          100.0         100.0
# 17    05/07/2019 3:00 AM  Rainbow Station Run_2          100.0         100.0
# 18    05/07/2019 4:00 AM  Rainbow Station Run_2          100.0         100.0
# 19    05/07/2019 5:00 AM  Rainbow Station Run_2          100.0         100.0
# 20    05/07/2019 6:00 AM  Rainbow Station Run_2          100.0         100.0
# 21    05/07/2019 7:00 AM  Rainbow Station Run_2          100.0         100.0
# 22    05/07/2019 8:00 AM  Rainbow Station Run_2          100.0         100.0
# 23    05/07/2019 9:00 AM  Rainbow Station Run_2          100.0         100.0
# 24   05/07/2019 10:00 AM  Rainbow Station Run_2          100.0         100.0
# 25   05/07/2019 11:00 AM  Rainbow Station Run_2          100.0         100.0
# 26   05/07/2019 12:00 PM  Rainbow Station Run_2          100.0         100.0
# 27    05/07/2019 1:00 PM  Rainbow Station Run_2          100.0         100.0
# 28    05/07/2019 2:00 PM  Rainbow Station Run_2          100.0         100.0
# 29    05/07/2019 3:00 PM  Rainbow Station Run_2          100.0         100.0
# ..                   ...                    ...            ...           ...
# 354   05/21/2019 4:00 AM  Rainbow Station Run_2          100.0         100.0
# 355   05/21/2019 5:00 AM  Rainbow Station Run_2          100.0         100.0
# 356   05/21/2019 6:00 AM  Rainbow Station Run_2          100.0         100.0
# 357   05/21/2019 7:00 AM  Rainbow Station Run_2          100.0         100.0
# 358   05/21/2019 8:00 AM  Rainbow Station Run_2          100.0         100.0
# 359   05/21/2019 9:00 AM  Rainbow Station Run_2          100.0         100.0
# 360  05/21/2019 10:00 AM  Rainbow Station Run_2          100.0         100.0
# 361  05/21/2019 11:00 AM  Rainbow Station Run_2          100.0         100.0
# 362  05/21/2019 12:00 PM  Rainbow Station Run_2          100.0         100.0
# 363   05/21/2019 1:00 PM  Rainbow Station Run_2          100.0         100.0
# 364   05/21/2019 2:00 PM  Rainbow Station Run_2          100.0         100.0
# 365   05/21/2019 3:00 PM  Rainbow Station Run_2          100.0         100.0
# 366   05/21/2019 4:00 PM  Rainbow Station Run_2          100.0         100.0
# 367   05/21/2019 5:00 PM  Rainbow Station Run_2          100.0         100.0
# 368   05/21/2019 6:00 PM  Rainbow Station Run_2          100.0         100.0
# 369   05/21/2019 7:00 PM  Rainbow Station Run_2          100.0         100.0
# 370   05/21/2019 8:00 PM  Rainbow Station Run_2          100.0         100.0
# 371   05/21/2019 9:00 PM  Rainbow Station Run_2          100.0         100.0
# 372  05/21/2019 10:00 PM  Rainbow Station Run_2          100.0         100.0
# 373  05/21/2019 11:00 PM  Rainbow Station Run_2          100.0         100.0
# 374  05/22/2019 12:00 AM  Rainbow Station Run_2          100.0         100.0
# 375   05/22/2019 1:00 AM  Rainbow Station Run_2          100.0         100.0
# 376   05/22/2019 2:00 AM  Rainbow Station Run_2          100.0         100.0
# 377   05/22/2019 3:00 AM  Rainbow Station Run_2          100.0         100.0
# 378   05/22/2019 4:00 AM  Rainbow Station Run_2          100.0         100.0
# 379   05/22/2019 5:00 AM  Rainbow Station Run_2          100.0         100.0
# 380   05/22/2019 6:00 AM  Rainbow Station Run_2          100.0         100.0
# 381   05/22/2019 7:00 AM  Rainbow Station Run_2          100.0         100.0
# 382   05/22/2019 8:00 AM  Rainbow Station Run_2          100.0         100.0
# 383   05/22/2019 9:00 AM  Rainbow Station Run_2          100.0         100.0
#
#      % Comm to MVT  FC Flow Time      FCLFlow      FCBFlow     FCEnergy  \
# 0            100.0      99.05930  22407.51367  20021.79785  20599.38721
# 1            100.0     100.00000  21416.54297  19079.35400  19656.09961
# 2            100.0     100.00000  23023.34961  20508.35742  21145.21143
# 3            100.0     100.00000  23226.59375  20682.09375  21314.19434
# 4            100.0     100.00000  23250.20703  20726.02148  21367.71094
# 5            100.0      96.12611  22339.58984  19895.50781  20512.68018
# 6            100.0     100.00000  22404.51953  19972.48828  20619.13184
# 7            100.0     100.00000  22962.36719  20511.06885  21196.71533
# 8            100.0      98.72070  25802.45313  23076.68994  23852.95898
# 9            100.0     100.00000  26367.51953  23601.20801  24392.75977
# 10           100.0     100.00000  25902.14063  23188.00781  23961.69873
# 11           100.0     100.00000  27685.31445  24742.23926  25545.79102
# 12           100.0     100.00000  29901.54883  26708.34961  27576.34863
# 13           100.0     100.00000  30267.37891  27025.89258  27913.13086
# 14           100.0     100.00000  30869.79297  27605.88867  28524.90527
# 15           100.0     100.00000  30313.94531  27133.42676  28070.20898
# 16           100.0     100.00000  30076.16211  26981.45801  27945.00586
# 17           100.0     100.00000  29847.06641  26811.48633  27784.54102
# 18           100.0     100.00000  30166.71680  27134.10938  28107.03516
# 19           100.0     100.00000  30735.45117  27668.17676  28648.73145
# 20           100.0     100.00000  31261.01563  28158.25195  29127.76465
# 21           100.0     100.00000  30929.81250  27822.01465  28739.87109
# 22           100.0     100.00000  29557.11133  26510.10352  27367.81055
# 23           100.0     100.00000  24998.76953  22390.71533  23100.56982
# 24           100.0     100.00000  21030.63086  18795.26367  19382.97363
# 25           100.0     100.00000  22420.35156  20025.84375  20641.84277
# 26           100.0     100.00000  22934.97461  20471.61768  21100.82080
# 27           100.0      99.03152  24414.21875  21816.39844  22479.54199
# 28           100.0      95.59278  22931.53320  20496.17725  21122.07568
# 29           100.0     100.00000  23077.85156  20604.46729  21233.87402
# ..             ...           ...          ...          ...          ...
# 354          100.0     100.00000  20528.94727  18118.01807  18617.07422
# 355          100.0     100.00000  20079.29492  17718.07764  18275.30273
# 356          100.0     100.00000  20794.83008  18317.45508  18909.45850
# 357          100.0     100.00000  22805.78125  20078.44629  20739.49365
# 358          100.0     100.00000  22649.89844  19933.71680  20582.96631
# 359          100.0     100.00000  32383.93164  28471.69043  29296.90430
# 360          100.0     100.00000  47958.75781  42242.28223  43465.57031
# 361          100.0     100.00000  51426.10156  45251.62207  46567.12793
# 362          100.0     100.00000  53290.28516  46943.47852  48377.39063
# 363          100.0     100.00000  53078.74609  46814.67480  48244.60840
# 364          100.0     100.00000  49933.17969  44035.84277  45289.77539
# 365          100.0     100.00000  42353.60156  37317.08789  38430.66504
# 366          100.0     100.00000  26277.07813  23152.13672  23868.46729
# 367          100.0     100.00000  22427.64648  19769.12549  20377.63477
# 368          100.0     100.00000  21293.73438  18753.00879  19321.86035
# 369          100.0     100.00000  23758.77539  20951.52686  21577.91602
# 370          100.0     100.00000  27112.20117  23924.97656  24636.88770
# 371          100.0     100.00000  27116.01953  23917.54395  24641.47852
# 372          100.0     100.00000  27612.41211  24348.79248  25071.75293
# 373          100.0     100.00000  22195.51563  19600.78271  20202.38232
# 374          100.0     100.00000  21715.32227  19181.50049  19780.57910
# 375          100.0     100.00000  21930.78125  19391.51807  20000.23389
# 376          100.0     100.00000  22121.40820  19576.54102  20210.41992
# 377          100.0     100.00000  22267.45898  19711.91602  20357.37451
# 378          100.0     100.00000  21859.05664  19339.40918  19981.30371
# 379          100.0     100.00000  21485.53516  18996.55078  19643.74805
# 380          100.0     100.00000  21296.37695  18792.10547  19422.20508
# 381          100.0     100.00000  24615.54102  21753.15674  22496.32324
# 382          100.0     100.00000  24629.46875  21749.07129  22429.37109
# 383          100.0     100.00000  24634.17773  21760.57910  22457.21484
#
#      FCStaticPressure      ...       Unnamed: 491  Unnamed: 492  Unnamed: 493  \
# 0           494.50015      ...                NaN           NaN           NaN
# 1           493.77655      ...                NaN           NaN           NaN
# 2           494.07809      ...                NaN           NaN           NaN
# 3           494.35162      ...                NaN           NaN           NaN
# 4           494.84909      ...                NaN           NaN           NaN
# 5           494.39310      ...                NaN           NaN           NaN
# 6           494.14651      ...                NaN           NaN           NaN
# 7           494.36432      ...                NaN           NaN           NaN
# 8           494.18475      ...                NaN           NaN           NaN
# 9           494.25058      ...                NaN           NaN           NaN
# 10          494.26306      ...                NaN           NaN           NaN
# 11          493.77090      ...                NaN           NaN           NaN
# 12          494.02588      ...                NaN           NaN           NaN
# 13          494.46039      ...                NaN           NaN           NaN
# 14          495.11484      ...                NaN           NaN           NaN
# 15          494.87057      ...                NaN           NaN           NaN
# 16          495.27454      ...                NaN           NaN           NaN
# 17          495.21683      ...                NaN           NaN           NaN
# 18          495.35294      ...                NaN           NaN           NaN
# 19          495.34628      ...                NaN           NaN           NaN
# 20          495.30685      ...                NaN           NaN           NaN
# 21          494.64835      ...                NaN           NaN           NaN
# 22          493.80759      ...                NaN           NaN           NaN
# 23          494.04315      ...                NaN           NaN           NaN
# 24          493.84140      ...                NaN           NaN           NaN
# 25          494.16504      ...                NaN           NaN           NaN
# 26          494.16071      ...                NaN           NaN           NaN
# 27          494.55048      ...                NaN           NaN           NaN
# 28          495.00537      ...                NaN           NaN           NaN
# 29          494.65384      ...                NaN           NaN           NaN
# ..                ...      ...                ...           ...           ...
# 354         494.93451      ...                NaN           NaN           NaN
# 355         494.61459      ...                NaN           NaN           NaN
# 356         493.76498      ...                NaN           NaN           NaN
# 357         493.71335      ...                NaN           NaN           NaN
# 358         493.74463      ...                NaN           NaN           NaN
# 359         493.81110      ...                NaN           NaN           NaN
# 360         494.71661      ...                NaN           NaN           NaN
# 361         493.97900      ...                NaN           NaN           NaN
# 362         494.39883      ...                NaN           NaN           NaN
# 363         494.93091      ...                NaN           NaN           NaN
# 364         495.09030      ...                NaN           NaN           NaN
# 365         494.50742      ...                NaN           NaN           NaN
# 366         494.28372      ...                NaN           NaN           NaN
# 367         494.27356      ...                NaN           NaN           NaN
# 368         493.67960      ...                NaN           NaN           NaN
# 369         494.19446      ...                NaN           NaN           NaN
# 370         494.44360      ...                NaN           NaN           NaN
# 371         494.26541      ...                NaN           NaN           NaN
# 372         494.16098      ...                NaN           NaN           NaN
# 373         494.72638      ...                NaN           NaN           NaN
# 374         494.66431      ...                NaN           NaN           NaN
# 375         494.99283      ...                NaN           NaN           NaN
# 376         495.18616      ...                NaN           NaN           NaN
# 377         495.30203      ...                NaN           NaN           NaN
# 378         495.07321      ...                NaN           NaN           NaN
# 379         494.67996      ...                NaN           NaN           NaN
# 380         493.85123      ...                NaN           NaN           NaN
# 381         494.73508      ...                NaN           NaN           NaN
# 382         494.78146      ...                NaN           NaN           NaN
# 383         495.00464      ...                NaN           NaN           NaN
#
#      Unnamed: 494  Unnamed: 495  Unnamed: 496  Unnamed: 497  CEESiNetQC  \
# 0             NaN           NaN           NaN           NaN       100.0
# 1             NaN           NaN           NaN           NaN       100.0
# 2             NaN           NaN           NaN           NaN       100.0
# 3             NaN           NaN           NaN           NaN       100.0
# 4             NaN           NaN           NaN           NaN       100.0
# 5             NaN           NaN           NaN           NaN       100.0
# 6             NaN           NaN           NaN           NaN       100.0
# 7             NaN           NaN           NaN           NaN       100.0
# 8             NaN           NaN           NaN           NaN       100.0
# 9             NaN           NaN           NaN           NaN       100.0
# 10            NaN           NaN           NaN           NaN       100.0
# 11            NaN           NaN           NaN           NaN       100.0
# 12            NaN           NaN           NaN           NaN       100.0
# 13            NaN           NaN           NaN           NaN       100.0
# 14            NaN           NaN           NaN           NaN       100.0
# 15            NaN           NaN           NaN           NaN       100.0
# 16            NaN           NaN           NaN           NaN       100.0
# 17            NaN           NaN           NaN           NaN       100.0
# 18            NaN           NaN           NaN           NaN       100.0
# 19            NaN           NaN           NaN           NaN       100.0
# 20            NaN           NaN           NaN           NaN       100.0
# 21            NaN           NaN           NaN           NaN       100.0
# 22            NaN           NaN           NaN           NaN       100.0
# 23            NaN           NaN           NaN           NaN       100.0
# 24            NaN           NaN           NaN           NaN       100.0
# 25            NaN           NaN           NaN           NaN       100.0
# 26            NaN           NaN           NaN           NaN       100.0
# 27            NaN           NaN           NaN           NaN       100.0
# 28            NaN           NaN           NaN           NaN       100.0
# 29            NaN           NaN           NaN           NaN       100.0
# ..            ...           ...           ...           ...         ...
# 354           NaN           NaN           NaN           NaN       100.0
# 355           NaN           NaN           NaN           NaN       100.0
# 356           NaN           NaN           NaN           NaN       100.0
# 357           NaN           NaN           NaN           NaN       100.0
# 358           NaN           NaN           NaN           NaN       100.0
# 359           NaN           NaN           NaN           NaN       100.0
# 360           NaN           NaN           NaN           NaN       100.0
# 361           NaN           NaN           NaN           NaN       100.0
# 362           NaN           NaN           NaN           NaN       100.0
# 363           NaN           NaN           NaN           NaN       100.0
# 364           NaN           NaN           NaN           NaN       100.0
# 365           NaN           NaN           NaN           NaN       100.0
# 366           NaN           NaN           NaN           NaN       100.0
# 367           NaN           NaN           NaN           NaN       100.0
# 368           NaN           NaN           NaN           NaN       100.0
# 369           NaN           NaN           NaN           NaN       100.0
# 370           NaN           NaN           NaN           NaN       100.0
# 371           NaN           NaN           NaN           NaN       100.0
# 372           NaN           NaN           NaN           NaN       100.0
# 373           NaN           NaN           NaN           NaN       100.0
# 374           NaN           NaN           NaN           NaN       100.0
# 375           NaN           NaN           NaN           NaN       100.0
# 376           NaN           NaN           NaN           NaN       100.0
# 377           NaN           NaN           NaN           NaN       100.0
# 378           NaN           NaN           NaN           NaN       100.0
# 379           NaN           NaN           NaN           NaN       100.0
# 380           NaN           NaN           NaN           NaN       100.0
# 381           NaN           NaN           NaN           NaN       100.0
# 382           NaN           NaN           NaN           NaN       100.0
# 383           NaN           NaN           NaN           NaN       100.0
#
#      Unnamed: 499  Unnamed: 500
# 0             NaN           NaN
# 1             NaN           NaN
# 2             NaN           NaN
# 3             NaN           NaN
# 4             NaN           NaN
# 5             NaN           NaN
# 6             NaN           NaN
# 7             NaN           NaN
# 8             NaN           NaN
# 9             NaN           NaN
# 10            NaN           NaN
# 11            NaN           NaN
# 12            NaN           NaN
# 13            NaN           NaN
# 14            NaN           NaN
# 15            NaN           NaN
# 16            NaN           NaN
# 17            NaN           NaN
# 18            NaN           NaN
# 19            NaN           NaN
# 20            NaN           NaN
# 21            NaN           NaN
# 22            NaN           NaN
# 23            NaN           NaN
# 24            NaN           NaN
# 25            NaN           NaN
# 26            NaN           NaN
# 27            NaN           NaN
# 28            NaN           NaN
# 29            NaN           NaN
# ..            ...           ...
# 354           NaN           NaN
# 355           NaN           NaN
# 356           NaN           NaN
# 357           NaN           NaN
# 358           NaN           NaN
# 359           NaN           NaN
# 360           NaN           NaN
# 361           NaN           NaN
# 362           NaN           NaN
# 363           NaN           NaN
# 364           NaN           NaN
# 365           NaN           NaN
# 366           NaN           NaN
# 367           NaN           NaN
# 368           NaN           NaN
# 369           NaN           NaN
# 370           NaN           NaN
# 371           NaN           NaN
# 372           NaN           NaN
# 373           NaN           NaN
# 374           NaN           NaN
# 375           NaN           NaN
# 376           NaN           NaN
# 377           NaN           NaN
# 378           NaN           NaN
# 379           NaN           NaN
# 380           NaN           NaN
# 381           NaN           NaN
# 382           NaN           NaN
# 383           NaN           NaN
#
# [384 rows x 501 columns]
